# %%
import numpy as np

# %%
# 1 Line 4 ATM
def lines1atm4():
    newStudentTimer = 0
    serveTimer = [0,0,0,0]
    queue = 0
    servedStudent = 0
    for i in range(30000):
        # 4 atm
        for x in range(4):
            #Serve time
            if(serveTimer[x] == 0):
                if(queue != 0):
                    queue -= 1
                    serveTimer[x] = np.random.randint(15,180)
                    servedStudent += 1
            else:
                serveTimer[x] -= 1
                if(serveTimer[x] < 0):
                    serveTimer[x] = 0
        # new student
        if(newStudentTimer == 0):
            newStudentTimer = np.random.randint(5,40)
            queue += 1
        else:
            newStudentTimer -= 1
    print("(1 lines 4 atm) Served student number " + str(servedStudent))
    return servedStudent

# %%
# 4 Lines 4 ATM

def lines4atm4():
    newStudentTimer = 0
    serveTimer = [0,0,0,0]
    queue = [0,0,0,0]
    servedStudent = 0
    for i in range(30000):
        # 4 atm
        for x in range(4):
            #Serve time
            if(serveTimer[x] == 0):
                if(queue[x] != 0):
                    queue[x] -= 1
                    serveTimer[x] = np.random.randint(15,180)
                    servedStudent += 1
            else:
                serveTimer[x] -= 1
                if(serveTimer[x] < 0):
                    serveTimer[x] = 0
        # new student
        if(newStudentTimer == 0):
            newStudentTimer = np.random.randint(5,40)
            index = 0
            small = 99
            for ix, val in enumerate(queue):
                if(small > val):
                    small = val
                    index = ix
            queue[index] += 1
        else:
            newStudentTimer -= 1
    print("(4 lines 4 atm) Served student number " + str(servedStudent))
    return servedStudent

# %%
lines1atm4()
# Out:
# (1 lines 4 atm) Served student number 1228
# 1228

# %%
lines4atm4()
# Out:
# (4 lines 4 atm) Served student number 1229
# 1229

# %%
lines4arr = []
for _ in range(200):
    lines4arr.append(lines4atm4())
lines1arr = []
for _ in range(200):
    lines1arr.append(lines1atm4())
# Out:
# (4 lines 4 atm) Served student number 1215
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1213
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1204
# (4 lines 4 atm) Served student number 1227
# (4 lines 4 atm) Served student number 1246
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1221
# (4 lines 4 atm) Served student number 1219
# (4 lines 4 atm) Served student number 1247
# (4 lines 4 atm) Served student number 1237
# (4 lines 4 atm) Served student number 1243
# (4 lines 4 atm) Served student number 1212
# (4 lines 4 atm) Served student number 1245
# (4 lines 4 atm) Served student number 1247
# (4 lines 4 atm) Served student number 1247
# (4 lines 4 atm) Served student number 1218
# (4 lines 4 atm) Served student number 1195
# (4 lines 4 atm) Served student number 1187
# (4 lines 4 atm) Served student number 1237
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1210
# (4 lines 4 atm) Served student number 1210
# (4 lines 4 atm) Served student number 1235
# (4 lines 4 atm) Served student number 1216
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1203
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1236
# (4 lines 4 atm) Served student number 1205
# (4 lines 4 atm) Served student number 1227
# (4 lines 4 atm) Served student number 1225
# (4 lines 4 atm) Served student number 1218
# (4 lines 4 atm) Served student number 1233
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1229
# (4 lines 4 atm) Served student number 1235
# (4 lines 4 atm) Served student number 1217
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1230
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1225
# (4 lines 4 atm) Served student number 1219
# (4 lines 4 atm) Served student number 1208
# (4 lines 4 atm) Served student number 1217
# (4 lines 4 atm) Served student number 1239
# (4 lines 4 atm) Served student number 1235
# (4 lines 4 atm) Served student number 1206
# (4 lines 4 atm) Served student number 1238
# (4 lines 4 atm) Served student number 1194
# (4 lines 4 atm) Served student number 1204
# (4 lines 4 atm) Served student number 1224
# (4 lines 4 atm) Served student number 1210
# (4 lines 4 atm) Served student number 1194
# (4 lines 4 atm) Served student number 1202
# (4 lines 4 atm) Served student number 1187
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1190
# (4 lines 4 atm) Served student number 1229
# (4 lines 4 atm) Served student number 1210
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1227
# (4 lines 4 atm) Served student number 1189
# (4 lines 4 atm) Served student number 1224
# (4 lines 4 atm) Served student number 1196
# (4 lines 4 atm) Served student number 1205
# (4 lines 4 atm) Served student number 1243
# (4 lines 4 atm) Served student number 1208
# (4 lines 4 atm) Served student number 1239
# (4 lines 4 atm) Served student number 1215
# (4 lines 4 atm) Served student number 1221
# (4 lines 4 atm) Served student number 1215
# (4 lines 4 atm) Served student number 1248
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1255
# (4 lines 4 atm) Served student number 1217
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1233
# (4 lines 4 atm) Served student number 1196
# (4 lines 4 atm) Served student number 1218
# (4 lines 4 atm) Served student number 1213
# (4 lines 4 atm) Served student number 1212
# (4 lines 4 atm) Served student number 1219
# (4 lines 4 atm) Served student number 1245
# (4 lines 4 atm) Served student number 1224
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1184
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1239
# (4 lines 4 atm) Served student number 1251
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1234
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1195
# (4 lines 4 atm) Served student number 1213
# (4 lines 4 atm) Served student number 1208
# (4 lines 4 atm) Served student number 1216
# (4 lines 4 atm) Served student number 1230
# (4 lines 4 atm) Served student number 1251
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1228
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1238
# (4 lines 4 atm) Served student number 1218
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1235
# (4 lines 4 atm) Served student number 1240
# (4 lines 4 atm) Served student number 1217
# (4 lines 4 atm) Served student number 1223
# (4 lines 4 atm) Served student number 1174
# (4 lines 4 atm) Served student number 1269
# (4 lines 4 atm) Served student number 1241
# (4 lines 4 atm) Served student number 1216
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1241
# (4 lines 4 atm) Served student number 1176
# (4 lines 4 atm) Served student number 1230
# (4 lines 4 atm) Served student number 1196
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1223
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1223
# (4 lines 4 atm) Served student number 1234
# (4 lines 4 atm) Served student number 1204
# (4 lines 4 atm) Served student number 1238
# (4 lines 4 atm) Served student number 1232
# (4 lines 4 atm) Served student number 1223
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1183
# (4 lines 4 atm) Served student number 1249
# (4 lines 4 atm) Served student number 1198
# (4 lines 4 atm) Served student number 1252
# (4 lines 4 atm) Served student number 1270
# (4 lines 4 atm) Served student number 1186
# (4 lines 4 atm) Served student number 1232
# (4 lines 4 atm) Served student number 1208
# (4 lines 4 atm) Served student number 1199
# (4 lines 4 atm) Served student number 1233
# (4 lines 4 atm) Served student number 1210
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1246
# (4 lines 4 atm) Served student number 1229
# (4 lines 4 atm) Served student number 1198
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1203
# (4 lines 4 atm) Served student number 1201
# (4 lines 4 atm) Served student number 1189
# (4 lines 4 atm) Served student number 1219
# (4 lines 4 atm) Served student number 1234
# (4 lines 4 atm) Served student number 1219
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1221
# (4 lines 4 atm) Served student number 1212
# (4 lines 4 atm) Served student number 1242
# (4 lines 4 atm) Served student number 1232
# (4 lines 4 atm) Served student number 1238
# (4 lines 4 atm) Served student number 1221
# (4 lines 4 atm) Served student number 1247
# (4 lines 4 atm) Served student number 1214
# (4 lines 4 atm) Served student number 1177
# (4 lines 4 atm) Served student number 1228
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1223
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1220
# (4 lines 4 atm) Served student number 1237
# (4 lines 4 atm) Served student number 1186
# (4 lines 4 atm) Served student number 1216
# (4 lines 4 atm) Served student number 1213
# (4 lines 4 atm) Served student number 1203
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1207
# (4 lines 4 atm) Served student number 1222
# (4 lines 4 atm) Served student number 1209
# (4 lines 4 atm) Served student number 1231
# (4 lines 4 atm) Served student number 1238
# (4 lines 4 atm) Served student number 1213
# (4 lines 4 atm) Served student number 1226
# (4 lines 4 atm) Served student number 1227
# (4 lines 4 atm) Served student number 1182
# (4 lines 4 atm) Served student number 1184
# (4 lines 4 atm) Served student number 1237
# (4 lines 4 atm) Served student number 1235
# (4 lines 4 atm) Served student number 1246
# (4 lines 4 atm) Served student number 1240
# (4 lines 4 atm) Served student number 1227
# (4 lines 4 atm) Served student number 1211
# (4 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1198
# (1 lines 4 atm) Served student number 1254
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1240
# (1 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1196
# (1 lines 4 atm) Served student number 1213
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1239
# (1 lines 4 atm) Served student number 1238
# (1 lines 4 atm) Served student number 1250
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1211
# (1 lines 4 atm) Served student number 1207
# (1 lines 4 atm) Served student number 1231
# (1 lines 4 atm) Served student number 1234
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1203
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1215
# (1 lines 4 atm) Served student number 1212
# (1 lines 4 atm) Served student number 1245
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1226
# (1 lines 4 atm) Served student number 1226
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1204
# (1 lines 4 atm) Served student number 1226
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1211
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1188
# (1 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1200
# (1 lines 4 atm) Served student number 1229
# (1 lines 4 atm) Served student number 1228
# (1 lines 4 atm) Served student number 1222
# (1 lines 4 atm) Served student number 1225
# (1 lines 4 atm) Served student number 1229
# (1 lines 4 atm) Served student number 1176
# (1 lines 4 atm) Served student number 1265
# (1 lines 4 atm) Served student number 1225
# (1 lines 4 atm) Served student number 1216
# (1 lines 4 atm) Served student number 1183
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1198
# (1 lines 4 atm) Served student number 1211
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1233
# (1 lines 4 atm) Served student number 1222
# (1 lines 4 atm) Served student number 1235
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1203
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1243
# (1 lines 4 atm) Served student number 1206
# (1 lines 4 atm) Served student number 1211
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1243
# (1 lines 4 atm) Served student number 1212
# (1 lines 4 atm) Served student number 1228
# (1 lines 4 atm) Served student number 1206
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1237
# (1 lines 4 atm) Served student number 1241
# (1 lines 4 atm) Served student number 1243
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1203
# (1 lines 4 atm) Served student number 1222
# (1 lines 4 atm) Served student number 1200
# (1 lines 4 atm) Served student number 1207
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1197
# (1 lines 4 atm) Served student number 1237
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1205
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1238
# (1 lines 4 atm) Served student number 1253
# (1 lines 4 atm) Served student number 1238
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1203
# (1 lines 4 atm) Served student number 1233
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1239
# (1 lines 4 atm) Served student number 1221
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1234
# (1 lines 4 atm) Served student number 1213
# (1 lines 4 atm) Served student number 1212
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1216
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1249
# (1 lines 4 atm) Served student number 1250
# (1 lines 4 atm) Served student number 1221
# (1 lines 4 atm) Served student number 1216
# (1 lines 4 atm) Served student number 1206
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1242
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1225
# (1 lines 4 atm) Served student number 1225
# (1 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1246
# (1 lines 4 atm) Served student number 1213
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1226
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1209
# (1 lines 4 atm) Served student number 1194
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1258
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1204
# (1 lines 4 atm) Served student number 1222
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1202
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1222
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1176
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1231
# (1 lines 4 atm) Served student number 1229
# (1 lines 4 atm) Served student number 1218
# (1 lines 4 atm) Served student number 1192
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1237
# (1 lines 4 atm) Served student number 1235
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1239
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1202
# (1 lines 4 atm) Served student number 1191
# (1 lines 4 atm) Served student number 1229
# (1 lines 4 atm) Served student number 1235
# (1 lines 4 atm) Served student number 1216
# (1 lines 4 atm) Served student number 1211
# (1 lines 4 atm) Served student number 1215
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1242
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1264
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1249
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1210
# (1 lines 4 atm) Served student number 1236
# (1 lines 4 atm) Served student number 1200
# (1 lines 4 atm) Served student number 1233
# (1 lines 4 atm) Served student number 1235
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1234
# (1 lines 4 atm) Served student number 1245
# (1 lines 4 atm) Served student number 1219
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1237
# (1 lines 4 atm) Served student number 1225
# (1 lines 4 atm) Served student number 1245
# (1 lines 4 atm) Served student number 1237
# (1 lines 4 atm) Served student number 1233
# (1 lines 4 atm) Served student number 1216
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1223
# (1 lines 4 atm) Served student number 1194
# (1 lines 4 atm) Served student number 1199
# (1 lines 4 atm) Served student number 1235
# (1 lines 4 atm) Served student number 1242
# (1 lines 4 atm) Served student number 1220
# (1 lines 4 atm) Served student number 1232
# (1 lines 4 atm) Served student number 1201
# (1 lines 4 atm) Served student number 1230
# (1 lines 4 atm) Served student number 1203
# (1 lines 4 atm) Served student number 1248
# (1 lines 4 atm) Served student number 1239
# (1 lines 4 atm) Served student number 1227
# (1 lines 4 atm) Served student number 1224
# (1 lines 4 atm) Served student number 1214
# (1 lines 4 atm) Served student number 1217
# (1 lines 4 atm) Served student number 1215
# (1 lines 4 atm) Served student number 1235

# %%
print("4 lines 4 ATMs average : " + str(np.average(lines4arr)))
print("1 lines 4 ATMs average : " + str(np.average(lines1arr)))
# Out:
# 4 lines 4 ATMs average : 1219.58
# 1 lines 4 ATMs average : 1221.79
